# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ngraph = ['1000','100']

# %% [markdown]
# ### Random

# %%
ngraph = ['1000','100']
train = np.load(f'Data/train_Random_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_Random_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile - Random {ngraph[0]}-{ngraph[1]} graphs")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BFS->BF

# %%
ngraph = ['1000','1000']
train = np.load(f'Data/train_BFS_BF_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_BFS_BF_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile BFS->BF {ngraph[0]}-{ngraph[1]} graphs")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BF->BFS

# %%
ngraph = ['1000','1000']
train = np.load(f'Data/train_BF_BFS_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_BF_BFS_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile BF->BFS {ngraph[0]}-{ngraph[1]} graphs")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BFS+Bf

# %%
ngraph = '1000'
train = np.load(f'Data/train_1BF+1BFS_{ngraph}.npy', allow_pickle=True)
val = np.load(f'Data/val_1BF+1BFS_{ngraph}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile 1BF+1BFS {ngraph} graphs")
plt.xlabel("epochs")
plt.show()
