# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ngraph = ['1000','100']

# %% [markdown]
# ### Random

# %%
train = np.load(f'Data/train_Random_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_Random_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile K=10 {ngraph[0]}-{ngraph[1]}")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BFS->BF

# %%
ngraph = ['1000','100']
train = np.load(f'Data/train_BFS_BF_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_BFS_BF_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile K=10 BFS->BF {ngraph[0]}-{ngraph[1]}")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BF->BFS

# %%
ngraph = ['1000','100']
train = np.load(f'Data/train_BF_BFS_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
val = np.load(f'Data/val_BF_BFS_{ngraph[0]}_{ngraph[1]}.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile K=10 BF->BFS {ngraph[0]}-{ngraph[1]}")
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# ### BFS+Bf

# %%
train = np.load(f'Data/train_1BF+1BFS_1_0.npy', allow_pickle=True)
val = np.load(f'Data/val_1BF+1BFS_1_0.npy', allow_pickle=True)
plt.rcParams['figure.figsize'] = (12,8)
plt.plot(train, '-b', label='train loss')
plt.plot(val.item()['bf'], '-r', label='val loss bf')
plt.plot(val.item()['bfs'], 'g', label='val loss bfs')
plt.legend(loc='upper right')
plt.title(f"Sequential Reptile")
plt.xlabel("epochs")
plt.show()
